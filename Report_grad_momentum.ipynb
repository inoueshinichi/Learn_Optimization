# %% [markdown]
# ### Momentum
# アイディア：パラメータxを物体の位置と考えて，慣性を追加する
# Point:パラメータ更新を慣性の法則的に行う。一つ前の更新結果$\tilde{\nu}$を考慮する。静止物体に力(更新値$-\alpha\frac{\partial L}{\partial\boldsymbol{W}}$)を加えて速度$\nu$(更新結果)を上げていく感じ。

# %% [markdown]
# $$
#     \boldsymbol{\nu}^t \leftarrow \eta\nu^{t-1} -\alpha\frac{\partial L}{\partial\boldsymbol{W}}^t \\
#     \boldsymbol{W}^{t+1} \leftarrow \boldsymbol{W}^t + \nu^t
# $$
# $\nu$が慣性項でMomentumと呼ばれる。$\eta$は勾配がゼロが続いたときに慣性項$\nu$がゼロになるようにする減衰率

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
class Momentum:
    def __init__(self, f, df, alpha=0.01, eta=0.9, eps=1e-6):
        self.f_= f
        self.df_= df
        self.alpha_= alpha
        self.eta_ = eta
        self.eps_= eps
        self.path_= None
        
    def solve(self, init):
        x = init
        v = np.zeros_like(x)
        path = []
        path.append(x)
        grad = self.df_(x)
        
        while (grad**2).sum() > self.eps_**2:
            grad = self.df_(x)
            v = self.eta_ * v - self.alpha_ * grad # 慣性項の計算
            x = x + v
            path.append(x)
            
        self.path_ = np.array(path)
        self.x_ = x
        self.opt_ = self.f_(x)

# %% [markdown]
# 勾配降下法

# %%
class GradientDescent:
    def __init__(self, f, df, alpha=0.01, eps=1e-6):
        self.f_= f
        self.df_= df
        self.alpha_= alpha
        self.eps_= eps
        self.path_= None
        
    def solve(self, init):
        x = init
        path = []
        path.append(x)
        grad = self.df_(x)
        
        while (grad**2).sum() > self.eps_**2:
            grad = self.df_(x)
            x = x - self.alpha_ * grad
            path.append(x)
            
        self.path_ = np.array(path)
        self.x_ = x
        self.opt_ = self.f_(x)

# %%
# 目的関数
def f(xx):
    x = xx[0]
    y = xx[1]
    return 5 * x ** 2 - 6 * x * y + 3 * y ** 2 + 6 * x - 6 * y

# 目的関数の微分
def df(xx):
    x = xx[0]
    y = xx[1]
    return np.array([10 * x - 6 * y + 6, -6 * x + 6 * y - 6])

# %%
algo = GradientDescent(f, df)
initial = np.array([0.5, 3.2])
algo.solve(initial)
print(algo.x_)
print(algo.opt_)
# Out:
# [3.40058430e-07 1.00000047e+00]
# -2.9999999999997167

# %% [markdown]
# ### Momentum Test

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))

# 左図 init (1.2, 3.2) SGD
ax[0].scatter(initial[0], initial[1], color="r", marker="o")
ax[0].plot(algo.path_[:, 0], algo.path_[:, 1], color="r", linewidth=1.5)

xs = np.linspace(-2, 2, 300)
ys = np.linspace(-2, 4, 400)
xmesh, ymesh = np.meshgrid(xs, ys)
xx = np.r_[xmesh.reshape(1, -1), ymesh.reshape(1, -1)]
levels = [-3, -2.9, -2.8, -2.6, -2.4, -2.2, -2, -1, 0, 1, 2, 3, 4]
ax[0].contour(xs, ys, f(xx).reshape(xmesh.shape), levels=levels, linestyles="dotted")

ax[0].set_ylim([-2, 4])
ax[0].set_xlim([-2, 2])
ax[0].set_title('GD')

# 右図 init (1.2, 3.2) Momentum
Nalgo = Momentum(f, df)
initial = np.array([0.5, 3.2])
Nalgo.solve(initial)
print(Nalgo.x_)
print(Nalgo.opt_)

ax[1].scatter(initial[0], initial[1], color="k", marker="o")
ax[1].plot(Nalgo.path_[:, 0], Nalgo.path_[:, 1], color="k", linewidth=1.5)
ax[1].contour(xs, ys, f(xx).reshape(xmesh.shape), levels=levels, linestyles="dotted")

ax[1].set_ylim([-2, 4])
ax[1].set_xlim([-2, 2])
ax[1].set_title('Momentum')

plt.show()
# Out:
# [-3.76324565e-07  9.99999653e-01]
# -2.9999999999997145
